# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sbn
# %matplotlib inline

# %%
data = pd.read_csv('Skyserver.csv', sep = ',', engine = 'python')
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# objid - ID объекта
# ra, dec - координаты небесного тела в экваториальной системе координат
# u,g,r,i,z - Система астрономических величин Туана-Ганна, отклик 5 полос телескопа
# run, rerun,camcol,field - функции, описывающее поле в изображении, снятом телескопом
# specobjid - идентификатор объекта
# class - класс объекта (галактика, звезда или квазар)
# redshift - красное смещение цвета
# plate - номер пластины, поля
# mjd - дата создания фрагмента данных
# fiberid - ID оптического волокна
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# 5     1.237650e+18  183.847174   0.173694  19.43133  18.46779  18.16451
# 6     1.237650e+18  183.864379   0.019201  19.38322  17.88995  17.10537
# 7     1.237650e+18  183.900081   0.187473  18.97993  17.84496  17.38022
# 8     1.237650e+18  183.924588   0.097246  17.90616  16.97172  16.67541
# 9     1.237650e+18  183.973498   0.081626  18.67249  17.71375  17.49362
# 10    1.237650e+18  183.979195   0.135998  19.29772  17.80227  17.18266
# 11    1.237650e+18  184.085331   0.112110  18.83307  17.51785  16.94273
# ...

# %%
print(data.shape)
# Out:
# (10000, 18)

# %%
cols = list(data.columns.values)
print(cols)
# Out:
# ['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol', 'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid']

# %%
data.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
data.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    0.000000e+00     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
data.corr()
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %%
sbn.jointplot(x="camcol", y="r", data=data)

# %%
plt.figure(figsize = (6, 6))

plt.scatter(data[data['class'] == 'STAR']['camcol'],
            data[data['class'] == 'STAR']['r'],
            alpha = 0.15,
            label = 'STAR',
            color = 'g')

plt.scatter(data[data['class'] == 'GALAXY']['camcol'],
            data[data['class'] == 'GALAXY']['r'],
            alpha = 0.1,
            label = 'GALAXY',
            color = 'r')

plt.scatter(data[data['class'] == 'QSO']['camcol'],
            data[data['class'] == 'QSO']['r'],
            alpha = 0.05,
            label = 'QSO',
            color = 'b')

plt.xlabel('camcol')
plt.ylabel('r')
plt.legend()
plt.grid()

# %%
sbn.jointplot(x="r", y="i", data=data)

# %%
plt.figure(figsize = (6, 6))

plt.scatter(data[data['class'] == 'STAR']['r'],
            data[data['class'] == 'STAR']['i'],
            alpha = 0.15,
            label = 'STAR',
            color = 'g')

plt.scatter(data[data['class'] == 'GALAXY']['r'],
            data[data['class'] == 'GALAXY']['i'],
            alpha = 0.1,
            label = 'GALAXY',
            color = 'r')

plt.scatter(data[data['class'] == 'QSO']['r'],
            data[data['class'] == 'QSO']['i'],
            alpha = 0.05,
            label = 'QSO',
            color = 'b')

plt.xlabel('r')
plt.ylabel('i')
plt.legend()
plt.grid()

# %% [markdown]
# ## Обработка пропущенных значений

# %%
data.count(axis=0)
# Out:
# objid        10000
# ra           10000
# dec          10000
# u            10000
# g            10000
# r            10000
# i            10000
# z            10000
# run          10000
# rerun        10000
# camcol       10000
# field        10000
# specobjid    10000
# class        10000
# redshift     10000
# plate        10000
# mjd          10000
# fiberid      10000
# dtype: int64

# %% [markdown]
# Пропущенные значения отсутствуют

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# objid, speconjid, fiberid являются ключами. rerun является идентичным у всех.

# %%
data = data.drop(['objid', 'specobjid', 'rerun', 'fiberid'], axis=1)

# %%
data.describe()
# Out:
#                  ra           dec             u             g             r  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     175.529987     14.836148     18.619355     17.371931     16.840963
# std       47.783439     25.212207      0.828656      0.945457      1.067764
# min        8.235100     -5.382632     12.988970     12.799550     12.431600
# 25%      157.370946     -0.539035     18.178035     16.815100     16.173333
# 50%      180.394514      0.404166     18.853095     17.495135     16.858770
# 75%      201.547279     35.649397     19.259232     18.010145     17.512675
# max      260.884382     68.542265     19.599900     19.918970     24.802040
#
#                   i             z           run        camcol         field  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      16.583579     16.422833    981.034800      3.648700    302.380100
# ...

# %% [markdown]
# Матрица ковариации

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (13, 13))
pass

# %% [markdown]
# ## Векторизация данных

# %% [markdown]
# Категориальные и числовые признаки

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print (categorical_columns)
print (numerical_columns)
# Out:
# ['class']
# ['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'camcol', 'field', 'redshift', 'plate', 'mjd']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# class ['STAR' 'GALAXY' 'QSO']

# %%
data_describe = data.describe(include = [object])
print(data_describe)
# Out:
#          class
# count    10000
# unique       3
# top     GALAXY
# freq      4998

# %% [markdown]
# Бинарные признаки

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] ['class']

# %% [markdown]
# Бинарных признаков нет, один текстовый - class

# %% [markdown]
# ## Нормализация количественных признаков

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                  ra           dec             u             g             r  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     175.529987     14.836148     18.619355     17.371931     16.840963
# std       47.783439     25.212207      0.828656      0.945457      1.067764
# min        8.235100     -5.382632     12.988970     12.799550     12.431600
# 25%      157.370946     -0.539035     18.178035     16.815100     16.173333
# 50%      180.394514      0.404166     18.853095     17.495135     16.858770
# 75%      201.547279     35.649397     19.259232     18.010145     17.512675
# max      260.884382     68.542265     19.599900     19.918970     24.802040
#
#                   i             z           run        camcol         field  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      16.583579     16.422833    981.034800      3.648700    302.380100
# ...

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#                  ra           dec             u             g             r  \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean   2.528964e-14 -1.193712e-15  5.576837e-14  1.001744e-13  3.000906e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.501106e+00 -8.019441e-01 -6.794599e+00 -4.836159e+00 -4.129529e+00
# 25%   -3.800279e-01 -6.098309e-01 -5.325737e-01 -5.889547e-01 -6.252604e-01
# 50%    1.018036e-01 -5.724204e-01  2.820708e-01  1.303110e-01  1.667660e-02
# 75%    5.444835e-01  8.255227e-01  7.721867e-01  6.750316e-01  6.290823e-01
# max    1.786276e+00  2.130163e+00  1.183295e+00  2.693976e+00  7.455837e+00
#
#                   i             z           run        camcol         field  \
# count  1.000000e+04  1.000000e+04  10000.000000  1.000000e+04  1.000000e+04
# mean   2.216041e-14 -4.109353e-14      0.000000  6.252776e-17 -1.676881e-16
# ...

# %% [markdown]
# ## Соединяем в одну таблицу

# %%
data = pd.concat((data_numerical, data[nonbinary_columns], data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (10000, 14)

# %%
data.describe()
# Out:
#                  ra           dec             u             g             r  \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean   2.528964e-14 -1.193712e-15  5.576837e-14  1.001744e-13  3.000906e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.501106e+00 -8.019441e-01 -6.794599e+00 -4.836159e+00 -4.129529e+00
# 25%   -3.800279e-01 -6.098309e-01 -5.325737e-01 -5.889547e-01 -6.252604e-01
# 50%    1.018036e-01 -5.724204e-01  2.820708e-01  1.303110e-01  1.667660e-02
# 75%    5.444835e-01  8.255227e-01  7.721867e-01  6.750316e-01  6.290823e-01
# max    1.786276e+00  2.130163e+00  1.183295e+00  2.693976e+00  7.455837e+00
#
#                   i             z           run        camcol         field  \
# count  1.000000e+04  1.000000e+04  10000.000000  1.000000e+04  1.000000e+04
# mean   2.216041e-14 -4.109353e-14      0.000000  6.252776e-17 -1.676881e-16
# ...

# %% [markdown]
# ## Х и у

# %%
X = data.drop(('class'), axis = 1)
y = data['class']
feature_names = X.columns
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'camcol', 'field',
#        'redshift', 'plate', 'mjd'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (10000, 13)
# (10000,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Обучающая и тестовая выборка

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 17)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 7000 3000

# %% [markdown]
# ## kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print (err_train, err_test)
# Out:
# 0.08742857142857142 0.10333333333333333

# %% [markdown]
# Подбор параметров

# %%
# %%time
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.09185714285714286 3
# CPU times: user 6.37 s, sys: 13.7 ms, total: 6.39 s
# Wall time: 6.81 s

# %% [markdown]
# Наилучшее количество ближайших соседей - 3

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.05085714285714286 0.09166666666666666

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC
svc = SVC(gamma = 'scale')
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.03757142857142857 0.043333333333333335

# %% [markdown]
# ## Значимость признаков

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'redshift' (0.496674)
#  2. feature 'plate' (0.148628)
#  3. feature '  mjd' (0.111636)
#  4. feature '    z' (0.062324)
#  5. feature '    i' (0.061497)
#  6. feature '    r' (0.042436)
#  7. feature '    g' (0.035209)
#  8. feature '    u' (0.022164)
#  9. feature '   ra' (0.005331)
# 10. feature '  dec' (0.005021)
# 11. feature 'field' (0.004578)
# 12. feature '  run' (0.003085)
# 13. feature 'camcol' (0.001417)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['dec', 'ra', 'dec'], dtype='object')

# %%
d_first = 13
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 13)

# %% [markdown]
# ## AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.09185714285714286 0.094

# %% [markdown]
# ## Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.020666666666666667

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
XPCAreducedTrain = pca.fit_transform(X_train)
XPCAreducedTest = pca.fit_transform(X_test)

print('Sklearn reduced X_train: \n', XPCAreducedTrain)
print('Sklearn reduced X_test: \n', XPCAreducedTest)
# Out:
# Sklearn reduced X_train:
#  [[ 1.47834929 -2.45594069]
#  [-6.26707177  0.33923975]
#  [ 3.80276876  2.69482387]
#  ...
#  [-2.17420645 -0.50043303]
#  [ 0.60071691 -1.00750611]
#  [-0.69015378  1.43243194]]
# Sklearn reduced X_test:
#  [[ 3.41682476  0.57645069]
#  [-3.8556617  -0.88773422]
#  [-0.97561667  2.40945614]
#  ...
#  [ 0.13495568 -2.18016877]
#  [-0.17101783 -1.29819222]
#  [ 2.68745271 -0.39463854]]

# %% [markdown]
# Построим точки на плоскости

# %%
concatData = np.vstack((XPCAreducedTrain,XPCAreducedTest))
plt.figure(figsize = (12,8))
plt.scatter(concatData[:,0], concatData[:,1], alpha = 0.4 )
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(XPCAreducedTrain, y_train)

err_train = np.mean(y_train != knn.predict(XPCAreducedTrain))
err_test  = np.mean(y_test  != knn.predict(XPCAreducedTest))

print(err_train, err_test)
# Out:
# 0.1672857142857143 0.425

# %%
from sklearn.decomposition import PCA
errors = []
for l in range(1,9):
    pca = PCA(n_components = l)
    XPCAreducedTrain = pca.fit_transform(X_train)
    XPCAreducedTest = pca.fit_transform(X_test)
    
    knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(XPCAreducedTrain, y_train)
    err_train = np.mean(y_train != knn.predict(XPCAreducedTrain))
    err_test  = np.mean(y_test  != knn.predict(XPCAreducedTest))
    
    errors.append([err_train, err_test])

print(errors)
# Out:
# [[0.239, 0.5503333333333333], [0.1672857142857143, 0.425], [0.08785714285714286, 0.291], [0.08928571428571429, 0.29233333333333333], [0.09071428571428572, 0.296], [0.07171428571428572, 0.317], [0.056, 0.37166666666666665], [0.05671428571428572, 0.36333333333333334]]

# %% [markdown]
# График зависимости ошибки от количества используемых компонент

# %%
i_range = range(1,9)
arr_errors = np.array(errors)
y_train = arr_errors[:,0]
y_test = arr_errors[:,1]
plt.figure(figsize = (12,8))
line_train, line_test = plt.plot(i_range, y_train, 'r^:', i_range, y_test, 'go:', lw = 5)

plt.axis([0.0, 9.0, 0.0, 0.6])
plt.grid()
plt.show()

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# array([[ 1.20782797,  0.39077419],
#        [ 0.30995389, -1.20523333],
#        [-1.26709807, -1.18980226],
#        ...,
#        [-1.21658984,  4.38640869],
#        [-1.26077249,  1.09619683],
#        [ 0.49612384,  0.988014  ]])

# %%
pca_X = pd.DataFrame(data=principal_components,
                     columns = ['principal_component_1', 'principal_component_2'])
pca_X.head()
# Out:
#    principal_component_1  principal_component_2
# 0               1.207828               0.390774
# 1               0.309954              -1.205233
# 2              -1.267098              -1.189802
# 3               1.615304               0.614064
# 4               1.264620               0.688047

# %%
final_data = pd.concat([pca_X, y], axis=1)
final_data.head()
# Out:
#    principal_component_1  principal_component_2   class
# 0               1.207828               0.390774    STAR
# 1               0.309954              -1.205233    STAR
# 2              -1.267098              -1.189802  GALAXY
# 3               1.615304               0.614064    STAR
# 4               1.264620               0.688047    STAR

# %%
plt.figure(figsize = (8, 8))

plt.scatter(final_data[final_data['class'] == 'STAR']['principal_component_1'],
            final_data[final_data['class'] == 'STAR']['principal_component_2'],
            alpha = 0.15,
            label = 'STAR',
            color = 'g')

plt.scatter(final_data[final_data['class'] == 'GALAXY']['principal_component_1'],
            final_data[final_data['class'] == 'GALAXY']['principal_component_2'],
            alpha = 0.1,
            label = 'GALAXY',
            color = 'r')

plt.scatter(final_data[final_data['class'] == 'QSO']['principal_component_1'],
            final_data[final_data['class'] == 'QSO']['principal_component_2'],
            alpha = 0.05,
            label = 'QSO',
            color = 'b')

plt.xlabel('Principal component 1')
plt.ylabel('Principal component 2')
plt.legend()
plt.grid()

# %% [markdown]
# ## Нейронная сеть

# %% [markdown]
# 1 скрытый слой на 100 нейронах

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 17)
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (100, 1), solver = 'lbfgs', activation = 'logistic', random_state = 17)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 1), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=17, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.018285714285714287 0.027333333333333334

# %% [markdown]
# 2 скрытых слоя на 100 нейронах

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100, 2), solver = 'lbfgs', activation = 'logistic', random_state = 17)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=17, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.004714285714285714 0.013333333333333334

# %% [markdown]
# На тестовой и тренировочной выборке ошибка уменьшилась

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# Подбор оптимального значения параметра регуляризации alpha

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100, 2), solver = 'lbfgs', activation = 'logistic', random_state = 17)
    mlp_model.fit(X_train, y_train)
    
    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

plt.semilogx(alpha_arr, train_err, 'r-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'b-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0037142857142857142 0.011666666666666667

# %% [markdown]
# Оптимальное значение alpha

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
alpha_opt = alpha_opt[0]
# Out:
# [0.56234133 1.        ]

# %% [markdown]
# Подбор оптимального количества нейронов

# %%
neurons = np.arange(10, 150, 15)
test_err = []
train_err = []
for neuron in neurons:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron,), solver = 'lbfgs', activation = 'logistic', random_state = 17)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    
plt.semilogx(neurons, train_err, 'b-o', label = 'train')
plt.semilogx(neurons, test_err, 'r-o', label = 'test')
plt.xlim([np.max(neurons), np.min(neurons)])
plt.title('Error vs. neurons')
plt.xlabel('neurons')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.009285714285714286 0.014

# %% [markdown]
# Оптимальное количество нейронов

# %%
neuron_opt = neurons[test_err == min_test_err]
print(neuron_opt)
neuron_opt = neuron_opt[0]
# Out:
# [10]

# %% [markdown]
# ### Классификатор с оптимальными значениями

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron_opt, 2), solver = 'lbfgs', activation = 'logistic', random_state = 17)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.5623413251903491,
#               batch_size='auto', beta_1=0.9, beta_2=0.999, early_stopping=False,
#               epsilon=1e-08, hidden_layer_sizes=(10, 2),
#               learning_rate='constant', learning_rate_init=0.001, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=17, shuffle=True, solver='lbfgs',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.008285714285714285 0.01

# %% [markdown]
# ## Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.012333333333333333

# %%
trees_arr = np.arange(25, 100, 5)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier(n_estimators = trees, oob_score=True)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)
    
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. trees Random forest')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Наблюдается переобучение

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.011666666666666667

# %% [markdown]
# Оптимальное количество деревьев

# %%
trees_opt = trees_arr[test_err == np.min(test_err)]
print(trees_opt)
trees_opt = trees_opt[0]
# Out:
# [40 50 55 70 95]

# %% [markdown]
# ## Gradient Boosted Trees

# %%
rf = ensemble.GradientBoostingClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.013333333333333334

# %%
trees_arr = np.arange(50, 1000, 50)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))
    
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. trees GBT')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.011666666666666667

# %% [markdown]
# Оптимальное количество деревьев

# %%
trees_opt = trees_arr[test_err == np.min(test_err)]
print(trees_opt)
trees_opt = trees_opt[0]
# Out:
# [100 150]

# %% [markdown]
# ## Выводы

# %% [markdown]
# kNN test_err = 0.09166666666666666
#
# SVC test_err = 0.043333333333333335
#
# Random Forest test_err = 0.012333333333333333
#
# Random Forest opt test_err = 0.011666666666666667
#
# Extremely Randomized Trees test_err = 0.020666666666666667
#
# AdaBoost test_err = 0.094
#
# GBT test_err = 0.013333333333333334
#
# GBT opt test_err = 0.011666666666666667
#
# neural network l1 test-err = 0.027333333333333334
#
# neural network l2 test-err = 0.013333333333333334
#
# Лучший результат показал метод Gradient Boosted Trees и Random Forest с оптимальным числом деревьев.
